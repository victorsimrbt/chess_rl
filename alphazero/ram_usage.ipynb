# %%
import objgraph

print(objgraph.show_most_common_types(limit=11))
# Out:
# function                   84767
# cell                       56123
# tuple                      51801
# dict                       41776
# list                       27234
# weakref                    13921
# builtin_function_or_method 9363
# member_descriptor          6273
# getset_descriptor          5941
# type                       5073
# Move                       4644
# None

# %%
from chess_env import * 
from q_network import *
from mcts import *             
env = ChessEnv()
q_model = Q_model()
for i in range(10):
    print(i)
    env.execute_episode(q_model,simulations = 10)
# Out:
# 1
# Move: 0
# Move: 1
# Move: 2
# Move: 3
# Move: 4
# Move: 5
# Move: 6
# Move: 7
# Move: 8
# Move: 9
# Move: 10
# Move: 11
# Move: 12
# Move: 13
# Move: 14
# Move: 15
# Move: 16
# Move: 17
# Move: 18
# Move: 19
# Move: 20
# Move: 21
# Move: 22
# Move: 23
# Move: 24
# Move: 25
# Move: 26
# Move: 27
# Move: 28

# %%
import objgraph

print(objgraph.show_most_common_types(limit=11))
# Out:
# function                         84767
# cell                             56123
# tuple                            51791
# dict                             41749
# list                             27176
# weakref                          13920
# builtin_function_or_method       9362
# member_descriptor                6273
# getset_descriptor                5941
# type                             5073
# Move                             4644
# wrapper_descriptor               3871
# module                           3385
# ModuleSpec                       3379
# method_descriptor                3298
# property                         3274
# SourceFileLoader                 3152
# Node                             2976
# Action                           2951
# TFDecorator                      2619
# FieldDescriptor                  2319
# _FieldProperty                   2319
# staticmethod                     2070
# set                              2048
# _tuplegetter                     1455
# ArgSpec                          1368
# classmethod                      1033
# _GenericAlias                    966
# frozenset                        928
# UnicodeValueChecker              680
# ABCMeta                          675
# cython_function_or_method        624
# Descriptor                       580
# GeneratedProtocolMessageType     580
# FileFinder                       507
# fused_cython_function            459
# Dimension                        424
# EnumValueDescriptor              421
# _Listener                        407
# weakproxy                        407
# Board                            373
# method                           354
# __pyx_scope_struct__with_phil    349
# PathMetadata                     279
# DistInfoDistribution             268
# MovedAttribute                   259
# _ObjectIdentityWrapper           236
# And                              204
# Enum                             201
# RegisterPForWithArgs             189
# instancemethod                   176
# TensorShape                      172
# ExtensionFileLoader              163
# Keys                             150
# RepeatedCompositeFieldContainer  146
# MovedModule                      136
# ForwardRef                       136
# FullArgSpec                      131
# DeprecatedArgSpec                128
# TFModuleWrapper                  116
# partial                          112
# MetaHasTraits                    112
# CachedProperty                   108
# frame                            106
# Regex                            105
# TagInfo                          104
# FileDescriptor                   101
# Unicode                          100
# Literal                          99
# slice                            98
# Bool                             86
# EnumMeta                         83
# StgDict                          82
# _TokenType                       82
# NullMessageListener              82
# argument                         81
# Optional                         80
# _NamedIntConstant                74
# EnumDescriptor                   73
# EnumTypeWrapper                  73
# UnaryRaggedElementwiseDispatcher 70
# pybind11_type                    69
# Config                           66
# Dim                              66
# Instance                         63
# TypeVar                          61
# TensorSpec                       61
# MatchFirst                       60
# HTTPStatus                       59
# LazyLoader                       58
# RegisteredOption                 56
# ArgInfo                          53
# Condition                        52
# ObserveHandler                   50
# _local                           50
# abstractproperty                 49
# Binding                          49
# classmethod_descriptor           47
# CField                           47
# TensorShapeProto                 47
# None
